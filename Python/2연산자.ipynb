# %% [markdown]
# # **[산술 연산자**]숫자 계산
#
# ![image.png](data:image/png;base64,...)

# %%
x = 3+4-10

print(x)
# Out:
# -3

# %%
x = 10*((20+5))

print(x)
# Out:
# 250

# %%
x = 2**3

print(x)
# Out:
# 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 4**3

print(x)
# Out:
# 64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 10%2

print(x)
# Out:
# 0

# %% [markdown]
# # **[대입 연산자]**
# x=3
#
# 변수 x에 3의 값을 대입한다

# %%
age = 15
name = "김나나"

print(name,age)
# Out:
# 김나나 15

# %%
x = 2
x += 1

print(x)
# Out:
# 3

# %% [markdown]
# # **[문자열 연산자]**
# 1.연결 연산자 : +

# %%
color = "노란색"
myColor = "나는 " + color + "을(를) 좋아합니다."

print(myColor)
# Out:
# 나는 노란색을(를) 좋아합니다.

# %% [markdown]
# 2.반복 연산자: *

# %%
animal = "호랑이"*5
print(animal)
# Out:
# 호랑이호랑이호랑이호랑이호랑이

# %%
line = "-"*30
print(line)
# Out:
# ------------------------------

# %% [markdown]
# # **[문자열 추출과 길이]**

# %%
string = "Every dog has its day."
print(string[-1])
# Out:
# .

# %% [markdown]
# # **[문자열 길이 구하기]**
#
# len()

# %%
a = "안녕하세요"
print(a)
print(len(a))
# Out:
# 안녕하세요
# 5

# %% [markdown]
# # **[연습문제]**
