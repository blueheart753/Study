# %% [markdown]
# # **[키보드 입력하기]**

# %% [markdown]
# 문자열 입력하기

# %%
animal = input("좋아하는 동물을 입력하세요: ")
print(animal)
# Out:
# 고양이

# %%
a = input("첫 번째 정수 입력하세요 :")
b = input("두 번째 정수 입력하세요 :")
c = a+b
print(c)
# Out:
# 1212

# %% [markdown]
# 정수 입력하기

# %% [markdown]
# # **[화면 출력하기]**

# %% [markdown]
# print()

# %%
age = 18
print("나의 나이는 ",age,"살 입니다.")
# Out:
# 나의 나이는  18 살 입니다.

# %% [markdown]
# sep 을 이용한 출력 - 항목 사이에 들어가는 문자열을 지정할 수 있습니다. (seperator)

# %% [markdown]
# 연결 연산자 +를 이용한 출력 (문자열)

# %% [markdown]
# %를 이용한 출력 - %d, %f %s

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 포맷팅 코드 연습

# %% [markdown]
# ## (연습문제)
#
# 년, 월, 일을 입력받아 저장하고
#
# '년/월/일' 형태로 출력하기
#
# ex) 2020/12/14
