# %% [markdown]
# # 반복문 - 특정 조건을 만족할 때까지 문장들을 반복 실행할 때 사용.
#
# ##파이썬의 반복문에는 while 문과 for문이 있다.

# %% [markdown]
# ## 안녕하세요? 5번 출력하기

# %%
i = 1
while i>0:
  print("안녕하세요!")
  i = i+1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1) 1~10의 숫자 중 홀수 출력하기
#
# 실행결과:
#
# 1
#
# 3
#
# 5
#
# 7
#
# 9

# %%
i = 1
while i<10:
  print(i)
  i +=2
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ### 2) 1부터 10 까지 누적 합계 구하기
#
# 실행결과:
#
# i : 1, sum : 1
#
# i : 2, sum : 3
#
# i : 3, sum : 6
#
# i : 4, sum : 10
#
# i : 5, sum : 15
#
# i : 6, sum : 21
#
# i : 7, sum : 28
#
# i : 8, sum : 36
#
# i : 9, sum : 45
#
# i : 10, sum : 55
#
# 합계 : 55

# %%
i = 1
sum = 1
while i<=10:
  print('i :',i,'sum :',sum)
  i += 1
  sum += 3
# Out:
# i : 1 sum : 1
# i : 2 sum : 4
# i : 3 sum : 7
# i : 4 sum : 10
# i : 5 sum : 13
# i : 6 sum : 16
# i : 7 sum : 19
# i : 8 sum : 22
# i : 9 sum : 25
# i : 10 sum : 28

# %% [markdown]
# ###3) 1~100 의 자연수 중에서 짝수의 합을 구하기
# 실행결과:
#
# 1~100의 짝수 합계 : 2550

# %%
n = 1
num = 0

while n <= 100:
  n = n+1
  if n % 2 == 0:
    num = num+n
print(num)
# Out:
# 2550

# %% [markdown]
# ###4)while 문을 이용하여 1000에서 10000까지의 자연수 중에서 9의 배수를 구하는 프로그램을 작성하시오. 단 한 줄에 10개씩 출력함.
#
# 실행결과:
#
# 1008 1017 1026 1035 1044 1053 1062 1071 1080 1089
#
# 1098 1107 1116 1125 1134 1143 1152 1161 1170 1179
#
# ...............
#
# 9918 9927 9936 9945 9954 9963 9972 9981 9990 9999

# %%
i = 1000
while i <= 10000:
    if i % 9 == 0:
        print(i, end=' ')
    i += 1
    if i % 10 == 0:
        print()
# Out:
# 1008
# 1017
# 1026
# 1035
# 1044
# 1053
# 1062
# 1071
# 1080 1089
# 1098
# 1107
# 1116
# 1125
# 1134
# 1143
# 1152
# 1161
# 1170 1179
# 1188
# 1197
# 1206
# 1215
# 1224
# 1233
# 1242
# 1251
# 1260 1269
# 1278
# 1287
# 1296
# 1305
# 1314
# 1323
# 1332
# 1341
# 1350 1359
# 1368
# 1377
# 1386
# 1395
# 1404
# 1413
# 1422
# 1431
# 1440 1449
# 1458
# 1467
# 1476
# 1485
# 1494
# 1503
# 1512
# 1521
# 1530 1539
# 1548
# 1557
# 1566
# 1575
# 1584
# 1593
# 1602
# 1611
# 1620 1629
# 1638
# 1647
# 1656
# 1665
# 1674
# 1683
# 1692
# 1701
# 1710 1719
# 1728
# 1737
# 1746
# 1755
# 1764
# 1773
# 1782
# 1791
# 1800 1809
# 1818
# 1827
# 1836
# 1845
# 1854
# 1863
# 1872
# 1881
# 1890 1899
# 1908
# 1917
# 1926
# 1935
# 1944
# 1953
# 1962
# 1971
# 1980 1989
# 1998
# 2007
# 2016
# 2025
# 2034
# 2043
# 2052
# 2061
# 2070 2079
# 2088
# 2097
# 2106
# 2115
# 2124
# 2133
# 2142
# 2151
# 2160 2169
# 2178
# 2187
# 2196
# 2205
# 2214
# 2223
# 2232
# 2241
# 2250 2259
# 2268
# 2277
# 2286
# 2295
# 2304
# 2313
# ...

# %% [markdown]
# ###5)키보드로 파운드를 입력 받아 킬로그램으로 환산하는 프로그램을 작성하시오.
#
# 조건:
#
# 키보드로 -1을 입력할 경우에 프로그램을 종료함.
#
# 힌트:
#
# 킬로그램 = 파운드 x 0.453592
#
# 실행결과:
#
# 파운드를 입력하세요(종료:-1) : 554
#
# 554 파운드(lb)는 251.29 킬로그램(kg)입니다.
#
# 파운드를 입력하세요(종료:-1) : -1
#
# 프로그램이 종료되었습니다!

# %%
while True:
    pounds = input("파운드를 입력하세요(종료:-1) :  ")
    if pounds == "-1":
        print("Program terminated!")
        break
    pounds = float(pounds)
    kilograms = pounds * 0.453592
    print(pounds,"파운드(1b)는",kilograms,"킬로그램(kg)입니다.")
# Out:
# 554.0 파운드(1b)는 251.289968 킬로그램(kg)입니다.
# Program terminated!
